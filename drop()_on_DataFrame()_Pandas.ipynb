# %%
import numpy as np
import pandas as pd


df = pd.DataFrame({"Age":[22,21,23,23,26],"Gender":['F','M','M','F','M']})
df
# Out:
#    Age Gender
# 0   22      F
# 1   21      M
# 2   23      M
# 3   23      F
# 4   26      M

# %%
df = df.assign(Salary=[20000,21000,30000,24000,32000])
df
# Out:
#    Age Gender  Salary
# 0   22      F   20000
# 1   21      M   21000
# 2   43      M   30000
# 3   23      F   24000
# 4   26      M   32000

# %%
df.insert(0,"S",['a','b','c','d','e'])
df
# Out:
#    S  Age Gender  Salary
# 0  a   22      F   20000
# 1  b   21      M   21000
# 2  c   43      M   30000
# 3  d   23      F   24000
# 4  e   26      M   32000

# %%
df = df.set_index('S')
df
# Out:
#    Age Gender  Salary
# S
# a   22      F   20000
# b   21      M   21000
# c   43      M   30000
# d   23      F   24000
# e   26      M   32000

# %%
df.drop(index=['b'])
# Out:
#    Age Gender  Salary
# S
# a   22      F   20000
# c   43      M   30000
# d   23      F   24000
# e   26      M   32000

# %%
df.drop(['b'],axis=0)
# Out:
#    Age Gender  Salary
# S
# a   22      F   20000
# c   43      M   30000
# d   23      F   24000
# e   26      M   32000

# %%
df.drop(index=['a','c','e'])
# Out:
#    Age Gender  Salary
# S
# b   21      M   21000
# d   23      F   24000

# %%
df.drop(['b','c'],axis=0)
# Out:
#    Age Gender  Salary
# S
# a   22      F   20000
# d   23      F   24000
# e   26      M   32000

# %%
df.drop(index=[0,1])    # index means index_row_names not index_row_number
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.drop(index=[0,1])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df
# Out:
#    Age Gender  Salary
# S
# a   22      F   20000
# b   21      M   21000
# c   43      M   30000
# d   23      F   24000
# e   26      M   32000

# %%
df.drop(columns=["Age","Salary"])
# Out:
#   Gender
# S
# a      F
# b      M
# c      M
# d      F
# e      M

# %%
df.drop(["Age","Salary"],axis=1)
# Out:
#   Gender
# S
# a      F
# b      M
# c      M
# d      F
# e      M

# %%
df.drop(["Age"],axis=1)
# Out:
#   Gender  Salary
# S
# a      F   20000
# b      M   21000
# c      M   30000
# d      F   24000
# e      M   32000

# %%
df.drop(columns=["Age"])
# Out:
#   Gender  Salary
# S
# a      F   20000
# b      M   21000
# c      M   30000
# d      F   24000
# e      M   32000

# %%
df.drop(columns=[0,2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.drop(columns=[0,2])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.drop("a")   # It can drop rows without any other parameter cause bydefault axis=0
# Out:
#    Age Gender  Salary
# S
# b   21      M   21000
# c   43      M   30000
# d   23      F   24000
# e   26      M   32000

# %%
df.drop("Age")   # # It can't drop columns without any other parameter cause bydefault axis=0 so we have use axis=1.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.drop("Age")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
df.drop("Age",axis=1)
# Out:
#   Gender  Salary
# S
# a      F   20000
# b      M   21000
# c      M   30000
# d      F   24000
# e      M   32000
